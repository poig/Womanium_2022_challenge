# %% [markdown]
# # Quantum pipeline using the Quantum Trainer

# %%
import warnings
warnings.filterwarnings("ignore")

import os
os.environ["TOKENIZERS_PARALLELISM"] = "false"

# %%
import numpy as np

BATCH_SIZE = 30
EPOCHS = 120
SEED = 2

# %% [markdown]
# ### Read in the data and create diagrams

# %%
def read_data(filename):
    labels, sentences = [], []
    with open(filename) as f:
        for line in f:
            t = int(line[0])
            labels.append([t, 1-t])
            sentences.append(line[1:].strip())
    return labels, sentences


train_labels, train_data = read_data('datasets/mc_train_data.txt')
dev_labels, dev_data = read_data('datasets/mc_dev_data.txt')
test_labels, test_data = read_data('datasets/mc_test_data.txt')

# %% [markdown]
# ### Create diagrams

# %%
from lambeq import BobcatParser

parser = BobcatParser(verbose='text')

raw_train_diagrams = parser.sentences2diagrams(train_data)
raw_dev_diagrams = parser.sentences2diagrams(dev_data)
raw_test_diagrams = parser.sentences2diagrams(test_data)
# Out:
# Tagging sentences.
# Parsing tagged sentences.
# Turning parse trees to diagrams.
# Tagging sentences.
# Parsing tagged sentences.
# Turning parse trees to diagrams.
# Tagging sentences.
# Parsing tagged sentences.
# Turning parse trees to diagrams.

# %% [markdown]
# ### Remove the cups

# %%
from lambeq import remove_cups

train_diagrams = [remove_cups(diagram) for diagram in raw_train_diagrams]
dev_diagrams = [remove_cups(diagram) for diagram in raw_dev_diagrams]
test_diagrams = [remove_cups(diagram) for diagram in raw_test_diagrams]

train_diagrams[0].draw()

# %% [markdown]
# ### Create circuits

# %%
from lambeq import AtomicType, IQPAnsatz

ansatz = IQPAnsatz({AtomicType.NOUN: 1, AtomicType.SENTENCE: 1},
                   n_layers=1, n_single_qubit_params=3)

train_circuits = [ansatz(diagram) for diagram in train_diagrams]
dev_circuits =  [ansatz(diagram) for diagram in dev_diagrams]
test_circuits = [ansatz(diagram) for diagram in test_diagrams]

train_circuits[0].draw(figsize=(9, 12))

# %% [markdown]
# ### Parameterise

# %%
from pytket.extensions.qiskit import AerBackend
from lambeq import TketModel

all_circuits = train_circuits+dev_circuits+test_circuits

backend = AerBackend()
backend_config = {
    'backend': backend,
    'compilation': backend.default_compilation_pass(2),
    'shots': 8192
}
model = TketModel.from_diagrams(all_circuits, backend_config=backend_config)

# %% [markdown]
# ### Define evaluation metric

# %%
loss = lambda y_hat, y: -np.sum(y * np.log(y_hat)) / len(y)  # binary cross-entropy loss
acc = lambda y_hat, y: np.sum(np.round(y_hat) == y) / len(y) / 2  # half due to double-counting

# %% [markdown]
# ### Initialize trainer

# %%
from lambeq import QuantumTrainer, SPSAOptimizer

trainer = QuantumTrainer(
    model,
    loss_function=loss,
    epochs=EPOCHS,
    optimizer=SPSAOptimizer,
    optim_hyperparams={'a': 0.05, 'c': 0.06, 'A':0.01*EPOCHS},
    evaluate_functions={'acc': acc},
    evaluate_on_train=True,
    verbose = 'text',
    seed=0
)

# %%
from lambeq import Dataset

train_dataset = Dataset(
            train_circuits,
            train_labels,
            batch_size=BATCH_SIZE)

val_dataset = Dataset(dev_circuits, dev_labels, shuffle=False)

# %% [markdown]
# ### Train

# %%
trainer.fit(train_dataset, val_dataset, logging_step=12)
# Out:
# Epoch 1:    train/loss: 2.0801   valid/loss: 1.8392   train/acc: 0.6000   valid/acc: 0.5333
# Epoch 12:   train/loss: 0.6100   valid/loss: 0.7619   train/acc: 0.5714   valid/acc: 0.4333
# Epoch 24:   train/loss: 0.5004   valid/loss: 0.6912   train/acc: 0.6857   valid/acc: 0.5667
# Epoch 36:   train/loss: 0.4908   valid/loss: 0.6744   train/acc: 0.6857   valid/acc: 0.5667
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [13], in <cell line: 1>()
# ----> 1 trainer.fit(train_dataset, val_dataset, logging_step=12)
#
# File ~\anaconda3\envs\womanium\lib\site-packages\lambeq\training\trainer.py:371, in Trainer.fit(self, train_dataset, val_dataset, evaluation_step, logging_step)
#     369 step += 1
#     370 x, y_label = batch
# --> 371 y_hat, loss = self.training_step(batch)
#     372 if (self.evaluate_on_train
#     373         and self.evaluate_functions is not None):
#     374     for metr, func in self.evaluate_functions.items():
#
# File ~\anaconda3\envs\womanium\lib\site-packages\lambeq\training\quantum_trainer.py:153, in QuantumTrainer.training_step(self, batch)
#     137 def training_step(
#     138         self,
#     139         batch: tuple[list[Any], np.ndarray]) -> tuple[np.ndarray, float]:
#     140     """Perform a training step.
#     141
#     142     Parameters
#    (...)
#     151
#     152     """
# --> 153     y_hat, loss = self.optimizer.backward(batch)
#     154     self.train_costs.append(loss)
#     155     self.optimizer.step()
#
# File ~\anaconda3\envs\womanium\lib\site-packages\lambeq\training\spsa_optimizer.py:134, in SPSAOptimizer.backward(self, batch)
#     132 xplus = self.project(x + self.ck * delta)
#     133 self.model.weights = xplus
# --> 134 y0 = self.model(diagrams)
#     135 loss0 = self.loss_fn(y0, targets)
#     136 xminus = self.project(x - self.ck * delta)
#
# File ~\anaconda3\envs\womanium\lib\site-packages\lambeq\training\model.py:64, in Model.__call__(self, *args, **kwds)
#      63 def __call__(self, *args: Any, **kwds: Any) -> Any:
# ---> 64     return self.forward(*args, **kwds)
#
# File ~\anaconda3\envs\womanium\lib\site-packages\lambeq\training\tket_model.py:136, in TketModel.forward(self, x)
#     118 def forward(self, x: list[Diagram]) -> np.ndarray:
#     119     """Perform default forward pass of a lambeq quantum model.
#     120
#     121     In case of a different datapoint (e.g. list of tuple) or
#    (...)
#     134
#     135     """
# --> 136     return self.get_diagram_output(x)
#
# File ~\anaconda3\envs\womanium\lib\site-packages\lambeq\training\tket_model.py:106, in TketModel.get_diagram_output(self, diagrams)
#      98     raise ValueError('Weights and/or symbols not initialised. '
#      99                      'Instantiate through '
#     100                      '`TketModel.from_diagrams()` first, '
#     101                      'then call `initialise_weights()`, or load '
#     102                      'from pre-trained checkpoint.')
#     104 lambdified_diagrams = [self._make_lambda(d) for d in diagrams]
#     105 tensors = Circuit.eval(
# --> 106     *[diag_f(*self.weights) for diag_f in lambdified_diagrams],
#     107     **self.backend_config,
#     108     seed=self._randint()
#     109 )
#     110 self.backend_config['backend'].empty_cache()
#     111 # discopy evals a single diagram into a single result
#     112 # and not a list of results
#
# File ~\anaconda3\envs\womanium\lib\site-packages\lambeq\training\tket_model.py:106, in <listcomp>(.0)
#      98     raise ValueError('Weights and/or symbols not initialised. '
#      99                      'Instantiate through '
#     100                      '`TketModel.from_diagrams()` first, '
#     101                      'then call `initialise_weights()`, or load '
#     102                      'from pre-trained checkpoint.')
#     104 lambdified_diagrams = [self._make_lambda(d) for d in diagrams]
#     105 tensors = Circuit.eval(
# --> 106     *[diag_f(*self.weights) for diag_f in lambdified_diagrams],
#     107     **self.backend_config,
#     108     seed=self._randint()
#     109 )
#     110 self.backend_config['backend'].empty_cache()
#     111 # discopy evals a single diagram into a single result
#     112 # and not a list of results
#
# File ~\anaconda3\envs\womanium\lib\site-packages\discopy\monoidal.py:509, in Diagram.lambdify.<locals>.<lambda>(*xs)
#     508 def lambdify(self, *symbols, **kwargs):
# --> 509     return lambda *xs: self.id(self.dom).then(*(
#     510         self.id(left) @ box.lambdify(*symbols, **kwargs)(*xs)
#     511         @ self.id(right) for left, box, right in self.layers))
#
# File ~\anaconda3\envs\womanium\lib\site-packages\discopy\monoidal.py:510, in <genexpr>(.0)
#     508 def lambdify(self, *symbols, **kwargs):
#     509     return lambda *xs: self.id(self.dom).then(*(
# --> 510         self.id(left) @ box.lambdify(*symbols, **kwargs)(*xs)
#     511         @ self.id(right) for left, box, right in self.layers))
#
# File ~\anaconda3\envs\womanium\lib\site-packages\discopy\quantum\gates.py:447, in Parametrized.lambdify(self, *symbols, **kwargs)
#     445 def lambdify(self, *symbols, **kwargs):
#     446     from sympy import lambdify
# --> 447     data = lambdify(symbols, self.data, dict(kwargs, modules=Tensor.np))
#     448     return lambda *xs: type(self)(data(*xs))
#
# File ~\anaconda3\envs\womanium\lib\site-packages\sympy\utilities\lambdify.py:875, in lambdify(args, expr, modules, printer, use_imps, dummify, cse)
#     873 else:
#     874     cses, _expr = (), expr
# --> 875 funcstr = funcprinter.doprint(funcname, iterable_args, _expr, cses=cses)
#     877 # Collect the module imports from the code printers.
#     878 imp_mod_lines = []
#
# File ~\anaconda3\envs\womanium\lib\site-packages\sympy\utilities\lambdify.py:1126, in _EvaluatorPrinter.doprint(self, funcname, args, expr, cses)
#    1123 if not iterable(args):
#    1124     args = [args]
# -> 1126 argstrs, expr = self._preprocess(args, expr)
#    1128 # Generate argument unpacking and final argument list
#    1129 funcargs = []
#
# File ~\anaconda3\envs\womanium\lib\site-packages\sympy\utilities\lambdify.py:1199, in _EvaluatorPrinter._preprocess(self, args, expr)
#    1197 dummy = Dummy()
#    1198 if isinstance(expr, Expr):
# -> 1199     dummy = uniquely_named_symbol(
#    1200         dummy.name, expr, modify=lambda s: '_' + s)
#    1201 s = self._argrepr(dummy)
#    1202 expr = self._subexpr(expr, {arg: dummy})
#
# File ~\anaconda3\envs\womanium\lib\site-packages\sympy\core\symbol.py:193, in uniquely_named_symbol(xname, exprs, compare, modify, **assumptions)
#     190 if not is_sequence(exprs):
#     191     exprs = [exprs]
#     192 names = set().union(
# --> 193     [i.name for e in exprs for i in e.atoms(Symbol)] +
#     194     [i.func.name for e in exprs for i in e.atoms(AppliedUndef)])
#     195 if modify is None:
#     196     modify = numbered_string_incr
#
# File ~\anaconda3\envs\womanium\lib\site-packages\sympy\core\symbol.py:193, in <listcomp>(.0)
#     190 if not is_sequence(exprs):
#     191     exprs = [exprs]
#     192 names = set().union(
# --> 193     [i.name for e in exprs for i in e.atoms(Symbol)] +
#     194     [i.func.name for e in exprs for i in e.atoms(AppliedUndef)])
#     195 if modify is None:
#     196     modify = numbered_string_incr
#
# File ~\anaconda3\envs\womanium\lib\site-packages\sympy\core\basic.py:518, in Basic.atoms(self, *types)
#     516 nodes = _preorder_traversal(self)
#     517 if types:
# --> 518     result = {node for node in nodes if isinstance(node, types)}
#     519 else:
#     520     result = {node for node in nodes if not node.args}
#
# File ~\anaconda3\envs\womanium\lib\site-packages\sympy\core\basic.py:518, in <setcomp>(.0)
#     516 nodes = _preorder_traversal(self)
#     517 if types:
# --> 518     result = {node for node in nodes if isinstance(node, types)}
#     519 else:
#     520     result = {node for node in nodes if not node.args}
#
# File ~\anaconda3\envs\womanium\lib\site-packages\sympy\core\basic.py:152, in Basic.__hash__(self)
#     148 def __hash__(self) -> int:
#     149     # hash cannot be cached using cache_it because infinite recurrence
#     150     # occurs as hash is needed for setting cache dictionary keys
#     151     h = self._mhash
# --> 152     if h is None:
#     153         h = hash((type(self).__name__,) + self._hashable_content())
#     154         self._mhash = h
#
# KeyboardInterrupt:

# %% [markdown]
# ### Show results

# %%
import matplotlib.pyplot as plt

fig, ((ax_tl, ax_tr), (ax_bl, ax_br)) = plt.subplots(2, 2, sharex=True, sharey='row', figsize=(10, 6))
ax_tl.set_title('Training set')
ax_tr.set_title('Development set')
ax_bl.set_xlabel('Iterations')
ax_br.set_xlabel('Iterations')
ax_bl.set_ylabel('Accuracy')
ax_tl.set_ylabel('Loss')

colours = iter(plt.rcParams['axes.prop_cycle'].by_key()['color'])
ax_tl.plot(trainer.train_epoch_costs, color=next(colours))
ax_bl.plot(trainer.train_results['acc'], color=next(colours))
ax_tr.plot(trainer.val_costs, color=next(colours))
ax_br.plot(trainer.val_results['acc'], color=next(colours))

test_acc = acc(model(test_circuits), test_labels)
print('Test accuracy:', test_acc)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [14], in <cell line: 17>()
#      14 ax_tr.plot(trainer.val_costs, color=next(colours))
#      15 ax_br.plot(trainer.val_results['acc'], color=next(colours))
# ---> 17 test_acc = acc(model(test_circuits), test_labels)
#      18 print('Test accuracy:', test_acc)
#
# File ~\anaconda3\envs\womanium\lib\site-packages\lambeq\training\model.py:64, in Model.__call__(self, *args, **kwds)
#      63 def __call__(self, *args: Any, **kwds: Any) -> Any:
# ---> 64     return self.forward(*args, **kwds)
#
# File ~\anaconda3\envs\womanium\lib\site-packages\lambeq\training\tket_model.py:136, in TketModel.forward(self, x)
#     118 def forward(self, x: list[Diagram]) -> np.ndarray:
#     119     """Perform default forward pass of a lambeq quantum model.
#     120
#     121     In case of a different datapoint (e.g. list of tuple) or
#    (...)
#     134
#     135     """
# --> 136     return self.get_diagram_output(x)
#
# File ~\anaconda3\envs\womanium\lib\site-packages\lambeq\training\tket_model.py:105, in TketModel.get_diagram_output(self, diagrams)
#      98     raise ValueError('Weights and/or symbols not initialised. '
#      99                      'Instantiate through '
#     100                      '`TketModel.from_diagrams()` first, '
#     101                      'then call `initialise_weights()`, or load '
#     102                      'from pre-trained checkpoint.')
#     104 lambdified_diagrams = [self._make_lambda(d) for d in diagrams]
# --> 105 tensors = Circuit.eval(
#     106     *[diag_f(*self.weights) for diag_f in lambdified_diagrams],
#     107     **self.backend_config,
#     108     seed=self._randint()
#     109 )
#     110 self.backend_config['backend'].empty_cache()
#     111 # discopy evals a single diagram into a single result
#     112 # and not a list of results
#
# File ~\anaconda3\envs\womanium\lib\site-packages\discopy\quantum\circuit.py:288, in Circuit.eval(self, backend, mixed, contractor, *others, **params)
#     286     return type(box)(box.dom, box.cod, box.array + 0j)
#     287 circuits = [circuit.to_tk() for circuit in (self, ) + others]
# --> 288 results, counts = [], circuits[0].get_counts(
#     289     *circuits[1:], backend=backend, **params)
#     290 for i, circuit in enumerate(circuits):
#     291     n_bits = len(circuit.post_processing.dom)
#
# File ~\anaconda3\envs\womanium\lib\site-packages\discopy\quantum\tk.py:133, in Circuit.get_counts(self, backend, *others, **params)
#     131 if compilation is not None:
#     132     for circuit in (self, ) + others:
# --> 133         compilation.apply(circuit)
#     134 handles = backend.process_circuits(
#     135     (self, ) + others, n_shots=n_shots, seed=seed)
#     136 counts = [backend.get_result(h).get_counts() for h in handles]
#
# ValueError: Non-unitary matrix passed to two_qubit_canonical

# %%
dir(trainer)
# Out:
# ['__abstractmethods__',
#  '__annotations__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__slots__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_abc_impl',
#  '_add_extra_chkpoint_info',
#  '_generate_stat_report',
#  '_load_extra_chkpoint_info',
#  '_train_results_epoch',
#  '_val_results_epoch',
#  'backend',
#  'epochs',
#  'evaluate_functions',
#  'evaluate_on_train',
#  'fit',
#  'from_checkpoint',
#  'load_training_checkpoint',
#  'log_dir',
#  'loss_function',
#  'model',
#  'optimizer',
#  'save_checkpoint',
#  'seed',
#  'start_epoch',
#  'start_step',
#  'train_costs',
#  'train_epoch_costs',
#  'train_results',
#  'training_step',
#  'use_tensorboard',
#  'val_costs',
#  'val_results',
#  'validation_step',
#  'verbose']
